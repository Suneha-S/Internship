# %%
#reading csv file
import pandas as pd
df = pd.read_csv(r'C:\Users\l\OneDrive\Desktop\Medical Appointment No Shows.csv')
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841190e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572130e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596270e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557660e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213490e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775120e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841190e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#checking null values
print(df.isnull().sum())
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
#heatmap to visualize null values
import seaborn as sns 
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
#counting number of duplicate values
df = pd.read_csv(r'C:\Users\l\OneDrive\Desktop\Medical Appointment No Shows.csv')
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
#droping duplicates
df_cleaned = df.drop_duplicates()
df_cleaned.to_csv(r'C:\Users\l\OneDrive\Desktop\Medical Appointment No Shows.csv', index=False)
print(df_cleaned.head())
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841190e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#Standardizing values and printing it 
df = pd.read_csv(r'C:\Users\l\OneDrive\Desktop\Medical Appointment No Shows.csv')
df['Gender'] = df['Gender'].str.lower().str.strip()
df['Gender'] = df['Gender'].replace({'f': 'female', 'm': 'male'})
df['Neighbourhood'] = df['Neighbourhood'].str.strip().str.title()
df['No-show'] = df['No-show'].str.strip().str.capitalize()
df.head()
# Out:
#       PatientId  AppointmentID  Gender          ScheduledDay  \
# 0  2.987250e+13        5642903  female  2016-04-29T18:38:08Z
# 1  5.589980e+14        5642503    male  2016-04-29T16:08:27Z
# 2  4.262960e+12        5642549  female  2016-04-29T16:19:04Z
# 3  8.679510e+11        5642828  female  2016-04-29T17:29:31Z
# 4  8.841190e+12        5642494  female  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    Jardim Da Penha            0             1
# 1  2016-04-29T00:00:00Z   56    Jardim Da Penha            0             0
# 2  2016-04-29T00:00:00Z   62      Mata Da Praia            0             0
# 3  2016-04-29T00:00:00Z    8  Pontal De Camburi            0             0
# 4  2016-04-29T00:00:00Z   56    Jardim Da Penha            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#Converting date columns to a consistent datetime format
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay'], errors='coerce')
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay'], errors='coerce')
df.head()
# Out:
#       PatientId  AppointmentID  Gender              ScheduledDay  \
# 0  2.987250e+13        5642903  female 2016-04-29 18:38:08+00:00
# 1  5.589980e+14        5642503    male 2016-04-29 16:08:27+00:00
# 2  4.262960e+12        5642549  female 2016-04-29 16:19:04+00:00
# 3  8.679510e+11        5642828  female 2016-04-29 17:29:31+00:00
# 4  8.841190e+12        5642494  female 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    Jardim Da Penha            0
# 1 2016-04-29 00:00:00+00:00   56    Jardim Da Penha            0
# 2 2016-04-29 00:00:00+00:00   62      Mata Da Praia            0
# 3 2016-04-29 00:00:00+00:00    8  Pontal De Camburi            0
# 4 2016-04-29 00:00:00+00:00   56    Jardim Da Penha            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0             1         0           0        0             0      No
# ...

# %%
# Cleaning column names lowercase, replace spaces and hyphens with underscores
df = pd.read_csv(r'C:\Users\l\OneDrive\Desktop\Medical Appointment No Shows.csv')
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_').str.replace('-', '_')
df.columns
# Out:
# Index(['patientid', 'appointmentid', 'gender', 'scheduledday',
#        'appointmentday', 'age', 'neighbourhood', 'scholarship', 'hipertension',
#        'diabetes', 'alcoholism', 'handcap', 'sms_received', 'no_show'],
#       dtype='object')

# %%
#converting date format
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay'])
df['ScheduledDay']
# Out:
# 0        2016-04-29 18:38:08+00:00
# 1        2016-04-29 16:08:27+00:00
# 2        2016-04-29 16:19:04+00:00
# 3        2016-04-29 17:29:31+00:00
# 4        2016-04-29 16:07:23+00:00
#                     ...
# 110522   2016-05-03 09:15:35+00:00
# 110523   2016-05-03 07:27:33+00:00
# 110524   2016-04-27 16:03:52+00:00
# 110525   2016-04-27 15:09:23+00:00
# 110526   2016-04-27 13:30:56+00:00
# Name: ScheduledDay, Length: 110527, dtype: datetime64[ns, UTC]

# %%
#converting date format
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay'])
df['AppointmentDay']
# Out:
# 0        2016-04-29 00:00:00+00:00
# 1        2016-04-29 00:00:00+00:00
# 2        2016-04-29 00:00:00+00:00
# 3        2016-04-29 00:00:00+00:00
# 4        2016-04-29 00:00:00+00:00
#                     ...
# 110522   2016-06-07 00:00:00+00:00
# 110523   2016-06-07 00:00:00+00:00
# 110524   2016-06-07 00:00:00+00:00
# 110525   2016-06-07 00:00:00+00:00
# 110526   2016-06-07 00:00:00+00:00
# Name: AppointmentDay, Length: 110527, dtype: datetime64[ns, UTC]

# %%
#checking data type
print(df.dtypes)
# Out:
# PatientId                     float64
# AppointmentID                   int64
# Gender                         object
# ScheduledDay      datetime64[ns, UTC]
# AppointmentDay    datetime64[ns, UTC]
# Age                             int64
# Neighbourhood                  object
# Scholarship                     int64
# Hipertension                    int64
# Diabetes                        int64
# Alcoholism                      int64
# Handcap                         int64
# SMS_received                    int64
# No-show                        object
# dtype: object

# %%
#saving the processed file 
output_path = r"C:\Users\l\OneDrive\Desktop\processed_Medical Appointment No Shows.csv"
df.to_csv(output_path, index=False)
print("Cleaned file saved to Desktop!")
# Out:
# Cleaned file saved to Desktop!
